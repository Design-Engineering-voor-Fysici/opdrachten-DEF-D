# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

bits = ([26,233,518,610,640,760,787,850,864])
lumens = ([0,34,233,295,216,347,389,879,1319])

def function(a,x,b):
    return (a * np.sqrt(x) + b)

init_values = ([2, 26]) 
popt, pcov = curve_fit(function, lumens, bits, p0=init_values)
a = popt[0]
b = popt[1]

a_onz = pcov[0,0]
b_onz = pcov[1,1]

print(a,b)

plt.figure(figsize=(12,8))
plt.plot(lumens,bits, 'r.')
plt.plot(lumens, a * np.sqrt(lumens) + b, 'g--')
#plt.errorbar(a_onz, b_onz)
plt.show()
# Out:
# 0.2508998567593823 380.9625259316704
# C:\Users\Cedric\AppData\Local\Temp\ipykernel_12508\2282593368.py:9: RuntimeWarning: invalid value encountered in sqrt
#   return (a * np.sqrt(x) + b)
