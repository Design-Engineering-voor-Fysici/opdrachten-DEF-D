# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

bits = ([26,233,518,610,640,760,787,850,864])
lumens = ([0,34,233,295,216,347,389,879,1319])

def function(a,x,b):
    return (a * np.sqrt(x) + b)


popt, pcov = curve_fit(function, lumens, bits)
a = popt[0]
b = popt[1]

a_onz = pcov[0,0]
b_onz = pcov[1,1]

plt.figure(figsize=(12,8))
plt.plot(lumens,bits, 'r.')
plt.show()
